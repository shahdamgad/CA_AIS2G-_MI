# %%
list_1 = [1,2,3,4,"Depi","Learning",True,[1,2,3,"true",["ml","Dl","gen"]]]
print(list_1)
# Out:
# [1, 2, 3, 4, 'Depi', 'Learning', True, [1, 2, 3, 'true', ['ml', 'Dl', 'gen']]]

# %%
print(type(list_1))
# Out:
# <class 'list'>

# %%
list_1[5]
# Out:
# 'Learning'

# %%
list_1[7][4][1]="deep learning"
list_1
# Out:
# [1,
#  2,
#  3,
#  4,
#  'Depi',
#  'Learning',
#  True,
#  [1, 2, 3, 'true', ['ml', 'deep learning', 'gen']]]

# %%
y= list("George")
y
# Out:
# ['G', 'e', 'o', 'r', 'g', 'e']

# %%
list_1.append("iti")
list_1
# Out:
# [1,
#  2,
#  3,
#  4,
#  'Depi',
#  'Learning',
#  True,
#  [1, 2, 3, 'true', ['ml', 'deep learning', 'gen']],
#  'iti']

# %%
x= list_1.append("iti")
print(list_1)
print(x)
# Out:
# [1, 2, 3, 4, 'Depi', 'Learning', True, [1, 2, 3, 'true', ['ml', 'deep learning', 'gen']], 'iti', 'iti']
# None

# %%
print(dir(list))
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
list_2 = ["depi","learning","python"]
list_2.insert(1,"iti")
list_2
list_2.insert(1,50)
list_2
# Out:
# ['depi', 50, 'iti', 'learning', 'python']

# %%
list_1 = ["depi","learning","python"]
list_1.extend("machine")
print(list_1)
# Out:
# ['depi', 'learning', 'python', 'm', 'a', 'c', 'h', 'i', 'n', 'e']

# %%
list_1 = ["depi","learning","python"]
new_list = list_1 + ["machine"]
print(list_1)
print(new_list)
# Out:
# ['depi', 'learning', 'python']
# ['depi', 'learning', 'python', 'machine']

# %%
list_1 = ["depi","learning","python","depi"]
list_1.remove("depi")
list_1
# Out:
# ['learning', 'python', 'depi']

# %%
list_1 = ["depi","learning","python","depi"]
x = list_1.pop()
print(x)
print(list_1)
print(type(x))
# Out:
# depi
# ['depi', 'learning', 'python']
# <class 'str'>

# %%
list_1 = ["depi","learning","python","depi"]
new_list = []
task = list_1.pop()      # remove depi put in task
new_list.append(task)    # add depi in the empty list
print(list_1)            # so we can reverse by using pop 
print(new_list)
print(task)
# Out:
# ['depi', 'learning', 'python']
# ['depi']
# depi

# %%
x=5
del x
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 3
#       1 x=5
#       2 del x
# ----> 3 print(x)
#
# NameError: name 'x' is not defined

# %%
list_1 = ["depi","learning","python","depi"]
del list_1[0]
print(list_1)
# Out:
# ['learning', 'python', 'depi']

# %%
del list_1[:]
print(list_1)
# Out:
# []

# %%
list_1 = ["depi","learning","python","depi"]
list_1.clear()
list_1
# Out:
# []

# %%
item = input("enter item to remove")
Input_list = ["amit","learning","python","machine learning","data science","deep learning"]
Input_list.remove(item)
print(Input_list)

# %%
list_1 = [1,2,3]
index_1 = list_1.index(2)
index_1
# Out:
# 1

# %%
list_1 = [1,2,3]
index_1 = list_1.count(2)
index_1
# Out:
# 1

# %%
list_1 = [200,100,70,50,400]
list_1.sort()
list_1
# Out:
# [50, 70, 100, 200, 400]

# %%
list_11 = [300,100,70,50,400]
x= sorted(list_11)
print(list_11)
print(x)
# Out:
# [300, 100, 70, 50, 400]
# [50, 70, 100, 300, 400]

# %%
list_11.reverse()
list_11
# Out:
# [400, 50, 70, 100, 300]

# %%
tuple_1 = ("depi","learning","python","depi")
print(type(tuple_1))
# Out:
# <class 'tuple'>

# %%
x=[1,2,3],[1,2,3]
type(x)                    # considered as tuple no other [] from outer
# Out:
# tuple

# %%
x=[[1,2,3],[1,2,3]]
type(x)
# Out:
# list

# %%
tuple_1 = ("depi","learning","python","depi")
tuple_1[2]= "machine learning"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 tuple_1 = ("depi","learning","python","depi")
# ----> 2 tuple_1[2]= "machine learning"
#
# TypeError: 'tuple' object does not support item assignment

# %%
set_one = {"depi","learning"}
print(type(set_one))
print(dir(set))
set_one[0]
# Out:
# <class 'set'>
# ['__and__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__iand__', '__init__', '__init_subclass__', '__ior__', '__isub__', '__iter__', '__ixor__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__rand__', '__reduce__', '__reduce_ex__', '__repr__', '__ror__', '__rsub__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__xor__', 'add', 'clear', 'copy', 'difference', 'difference_update', 'discard', 'intersection', 'intersection_update', 'isdisjoint', 'issubset', 'issuperset', 'pop', 'remove', 'symmetric_difference', 'symmetric_difference_update', 'union', 'update']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       1 set_one = {"depi","learning"}
# ...

# %%
set_1 = {3,1,4,1,5,9,2}
set_1.add(6)
print(set_1)
# Out:
# {1, 2, 3, 4, 5, 6, 9}

# %%
data1 = {101,102,103,104}
data2 = {103,104,105,106}
print(data1.intersection(data2))
print(data1.union(data2))
# Out:
# {104, 103}
# {101, 102, 103, 104, 105, 106}

# %%
words ={"python","python","depi"}
words
unique_words=list(set(words))
unique_words
# Out:
# ['python', 'depi']

# %%
dict_1 = {"k1":12.5,"k2":"depi","k3":"python"}
print(dir(dict))
print(dict_1["k1"])
# Out:
# ['__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__ior__', '__iter__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__ror__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'clear', 'copy', 'fromkeys', 'get', 'items', 'keys', 'pop', 'popitem', 'setdefault', 'update', 'values']
# 12.5

# %%
dict_1["k1"]="machine learning"
print(dict_1["k1"])
# Out:
# machine learning

# %%
chatbot = {
    "hello":"hello how can i help you",
    "python":"python is a programming language",
    "AI":"that enable to learn from the data"
}
print(chatbot.keys())
print(chatbot.items())
print(chatbot.values())

question = input("question: ").lower()
print(chatbot.get(question, "your query not found"))
# Out:
# dict_keys(['hello', 'python', 'AI'])
# dict_items([('hello', 'hello how can i help you'), ('python', 'python is a programming language'), ('AI', 'that enable to learn from the data')])
# dict_values(['hello how can i help you', 'python is a programming language', 'that enable to learn from the data'])
# hello how can i help you

# %%
num1=float(input("enter num1"))
num2=float(input("enter num2"))
print(f"num1 {num1}, num2 {num2}", num1+num2)
print(f"num1 {num1}, num2 {num2}", num1-num2)
print(f"num1 {num1}, num2 {num2}", num1*num2)
print(f"num1 {num1}, num2 {num2}", num1/num2)
# Out:
# num1 2.0, num2 5.0 7.0
# num1 2.0, num2 5.0 -3.0
# num1 2.0, num2 5.0 10.0
# num1 2.0, num2 5.0 0.4

# %%
a = 200
b= 33
if b> a:
    print("b is graeter than a")
else:
    print("b is not graeter than a")
# Out:
# b is not graeter than a
