# %% [markdown]
# # Task-1

# %%
email= "Amit_ml@gmail.edu"
email.count("@")
# Out:
# 1

# %%
x= email.split("@")
print (x)
# Out:
# ['Amit_ml', 'gmail.edu']

# %%
x= email.split("@")[1]
print (x)
# Out:
# gmail.edu

# %%
if email.count("@") or "." not in email.split("@")[1]:
    print("invalid email")
else:
    Username = email.split("@")[0]
    Domain = email[8:13:1]
    print("Username is" ,Username ,",", "Domain is", Domain)
# Out:
# invalid email

# %%
if email.endswith(".com"):
    print("Commercial Domain")
elif email.endswith(".edu"):
    print("Educational Domain")
else:
    print("Other Domain")
# Out:
# Educational Domain

# %% [markdown]
# # Task-2

# %%
Encoded_message ="###!!@mocleW EPGTQ!!!6789"
core = Encoded_message[6:18:1]
print(core)
# Out:
# mocleW EPGTQ

# %%
words= core.split()
print(words)
reverse= print(words[0][::-1])
first_word= words[0][::-1]
# Out:
# ['mocleW', 'EPGTQ']
# Welcom

# %%
second_word = words[1][1:]   # Remove the first letter E
print(second_word)
# Out:
# PGTQ

# %%
Decoded = print(first_word , second_word)
# Out:
# Welcom PGTQ

# %% [markdown]
# # Task-3

# %%
Encoded_Message = "&&&**$gnirtS PLIO!!@1234"
core = Encoded_Message[6:17:1]
print(core)
# Out:
# gnirtS PLIO

# %%
words= core.split()
print(words)
reverse= print(words[0][::-1])
first_word= words[0][::-1]
# Out:
# ['gnirtS', 'PLIO']
# String

# %%
second_word = words[1]
second_word = second_word.replace("I", "E")
second_word = second_word.replace("O", "U")
print(second_word)
# Out:
# PLEU

# %%
print("Decoded Message:", first_word, second_word)
# Out:
# Decoded Message: String PLEU

# %% [markdown]
# # Task-4

# %%
Encoded_Message="##$$$@!yalpstcejorp EPUVT****9887 " 
core = Encoded_Message[7:25:1]
print(core)
# Out:
# yalpstcejorp EPUVT

# %%
words= core.split()
print(words)
reverse= print(words[0][::-1])
first_word= words[0][::-1]
# Out:
# ['yalpstcejorp', 'EPUVT']
# projectsplay

# %%
second_word = words[1]
second_word = second_word.replace("E", "A")
second_word = second_word.replace("U", "O")
print(second_word)
# Out:
# APOVT

# %%
print("Decoded Message:", first_word, second_word)
# Out:
# Decoded Message: projectsplay APOVT
