# %%
x= 5
print(x)
# Out:
# 5

# %%
print("my name shahd", 22)
# Out:
# my name shahd 22

# %% [markdown]
# # welcome to python
# ## basic python

# %%
name= "shahd"
age= 22
print("my name is {} and my age is {}".format(name,age))
# Out:
# my name is shahd and my age is 22

# %%
print(f"my name is {name} and my age is {age}")
# Out:
# my name is shahd and my age is 22

# %%
def info():
    return f"my name is {name} and my age is {age}"

# %%
name= "shahd"
age= "22"
course="Depi-Ai"
print(f"my name is {name} and my age is {age} and enrolled in course {course}")
# Out:
# my name is shahd and my age is 22 and enrolled in course Depi-Ai

# %%
lst_1=[1,2,3,4,5]
print(type(lst_1))
list
# Out:
# <class 'list'>

# %%
tup_1=(1,2,3,4,5)
print(type(tup_1))
# Out:
# <class 'tuple'>

# %%
tup_1=(1)
print(type(tup_1))
# Out:
# <class 'int'>

# %%
tup_1=(1,2,3,4,5)
print(id(tup_1))
print(type(tup_1))
tup_1=(3,4)
tup_1
id(tup_1)
# Out:
# 2065961766320
# <class 'tuple'>
# 2065961144192

# %%
set_1={1,2,3}
print(type(set_1))
set
# Out:
# <class 'set'>

# %%
dict_1={'k1':30, 'k2':20}
print(type(dict_1))
dict
# Out:
# <class 'dict'>
# dict

# %%
x= "depi for ml"
type(x)
print(x[0])
print(x[-1])
print(x[5:8:1])    # slicing
print(x[::-1])     # inverse
# Out:
# d
# l
# for
# lm rof iped

# %%
name = "Depi for machine learning for everyone"
capital =name.upper()
capital
capital.lower()
# Out:
# 'depi for machine learning for everyone'

# %%
name= "depi learning"
name.replace("depi","machine")
# Out:
# 'machine learning'

# %%
name= "depi for ai"
name.capitalize()    #capitalize first letter
# Out:
# 'Depi for ai'

# %%
name= "depi for ai"
name.title()
# Out:
# 'Depi For Ai'

# %%
name= "depi for machine learning and depi for genai"
name.count("depi")
# Out:
# 2

# %%
name= "depi for machine learning and depi for genai"
x= name.split()
x
# Out:
# ['depi', 'for', 'machine', 'learning', 'and', 'depi', 'for', 'genai']

# %%
new_x=' '.join(x)
new_x
# Out:
# 'depi for machine learning and depi for genai'

# %%
name= "depi for machine learning and depi for genai"
name.startswith("depi")
name.endswith("depi")
# Out:
# False

# %%
print("hello world for \"students\" in depi")
# Out:
# hello world for "students" in depi

# %%
print("hello world for\t students in depi")
# Out:
# hello world for	 students in depi

# %%
print("hello world for\b students in depi")   #remoove r in for
# Out:
# hello world fo students in depi
