# %%
x=10

# %%
''' this class care about student information'''

class Student:

    name="Depi"
    age = 5

    def std_info(self):
        print("hello depi students")

# %%
s1= Student()
s1.name = "shahd"
s1.age =22
print(s1.name)
print(s1.age)
s1
s1.std_info()
# Out:
# shahd
# 22
# hello depi students

# %%
s2 = Student()
s2.std_info()
# Out:
# hello depi students

# %%
class Student:
    def __init__(self, name = "test", age= 40) -> None:
        self.name = name
        self.age = age

    def std_info(self):
        return f"my name is{self.name} , my age is {self.age}"

# %%
s1 = Student()

# %%
s1 = Student("shahd", 22)

# %%
name = input("Enter your name: ")
age = int(input("Enter your age: "))

# %%
from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def move(self):
        pass

class Bird(Animal):
    def move(self):
        print("I can fly")

class Cat(Animal):
    def move(self):
        print("I can move")

a = Bird()
a.move()
# Out:
# I can fly

# %%
class Student:
    def __init__(self, name = "test", age= 40) -> None:
        self.name = name
        self.age = age

    def std_info(self):
        return f"my name is{self.__name} , my age is {self.age}"

# %%
s1.__name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 s1.__name
#
# AttributeError: 'Student' object has no attribute '__name'

# %%
s1._Student__name    # it sould run
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 s1._Student__name
#
# AttributeError: 'Student' object has no attribute '_Student__name'

# %%
class Student:
    def __init__(self, _name , age) -> None:
        self.name = name
        self.age = age

    def get_info(self):
        return f"my name is{self._name} , my age is {self.age}"

# %%
s1=Student("shahd", 22)

# %%
s1._name          #  should run      #  _ is protected __ is private
#s1._Student__name
# Out:
# 'ss'

# %%
s1.__name    # not run because it is private and we can access it by using _Student__name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 s1.__name    # not run because it is private and we can access it by using _Student__name
#
# AttributeError: 'Student' object has no attribute '__name'

# %%
s1._Student__name   # run because it is private and we can access it by using _Student__name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 s1._Student__name   # run because it is private and we can access it by using _Student__name
#
# AttributeError: 'Student' object has no attribute '_Student__name'

# %%
class Student:
    def __init__(self , age) -> None:
     
        self._age = age
    @property                           # getter and setter to acees private and protected
    def age(self):
        return self._age
    @age.setter
    def age(self,value):
        if value < 0:
            raise ValueError("Age cannot be negative")
        self._age = value

# %%
s1= Student("ss",22)
s1.name
# Out:
# 'ss'

# %%
s1.age
# Out:
# 22

# %% [markdown]
# ## polymorphism

# %%
class Shape:
    def calculate_area(self):
        pass

class Circle(Shape):
    def __init__(self, radius) -> None:
        self.radius = radius

    def calculate_area(self):
        return 3.14 * self.radius ** 2

class Square(Shape):
    def __init__(self, side) -> None:
        self.side = side

    def calculate_area(self):
        return self.side ** 2

if __name__ == "__main__":
    circle = Circle(5)
    square = Square(4)

    print("Circle area:", circle.calculate_area())
    print("Square area:", square.calculate_area())
# Out:
# Circle area: 78.5
# Square area: 16

# %%
calc(int)
calc(int,int)

# %%
class calc:
    def add(self, a):
        return a 

    def add(self, a, b):
        return a + b

# %%
c1 = calc()
c1.add(20)          # it override the first add method and it will call the second add method and it will give an error because it is missing one argument
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 c1 = calc()
# ----> 2 c1.add(20)
#
# TypeError: calc.add() missing 1 required positional argument: 'b'

# %%
class calc:
    def add(self, a):
        return a 

    def add(self, a, b=0):   # we solve by make b=0
        return a + b

# %%
c1 = calc()
c1.add(20)
# Out:
# 20

# %%
def add(*name):
    (*name )=(2,3,5,4,8,.....)
# Out:
#   Cell In[7], line 2
#     (*name )=(2,3,5,4,8,.....)
#      ^
# SyntaxError: cannot use starred expression here
